# %%
# %%html
#
# <canvas id="CarGarage"></canvas>
#
# <script>
# const canvas = document.getElementById("360Image");
# const ctx = canvas.getContext('2d');
#
# // Load your 360-degree image here
# const image = new Image();
#   image.src = '{{https://lh3.googleusercontent.com/pw/ADCreHeCUDkkgXkgjAffgDawIVJ1t6dSMRS4e00p3lqVUPJrydJmnOitBfj3KaBf78ebKtCCYW4AIX33fOvYW2_mypJ6eIJirgDT3oD6AKTOVeaO3Y2PYyGCsJyLJxeq_hQtp6NTE1IhBvXpkpcHo9eamIKvFyof74wyobeQeGo11EX9f6YhsfmFRSbkbf0WgNcLL-YoCryfa6uI2Y_W1TwRKl6tOwtgoeEK6b490z5m4lOw0aV07F34gbJLRV5BxQu-6d64W5VObnyYaWZ9oUtWdssrxK8BoJBcOknpv4VWnd4RpOk2byJLlJQ9ttRP1DOrfhz1OuW3I35KvLgByZghEKziDSKJ37gSeGP0exBbaypqpSzp5iZUbMGOt9c4AUUGP5d-twkKhsrpuBpzCnwFQtsgzWNeK6Z7Vq4CRS-mN0fAGubzEaAb0CNC247dvjJdtWzwYHDXZQLF_BmJhEJT8RZBddAY4MvAl_zYfHa94u7TotIgwFJ91mdN6HljM9nYCZrnBs4e9LfIbeDiUEV8XmMjUulVfhmoGNpJps-olbJ4E8hws-Zsv9iUo_hjIVrSJzqU7ZRNH4mJPZqqpBEZ_ZuEdEyUGEfF_xfo3RWmnQV2gYrjV9MnK-ETTppqRHzsl2sNRys7st_tu87ATqa0rq6kqxRP2cnZmn64QyVxVQ3GjWmD-zVtO0CpFUY2ynL8FzxE3OCARKjB34cQDc43a9wC4IZAdrj80EvdChQpKJp6Zdat-hLaoKeYBoH8D6e5xhEqpGb-q6hAtvNFC2SsreKvKQAXQDTCmd_RDcp1pTS8_FBb7BCsyG2g7kIiVYyFlze0pGNGa6pjeOYwpeXstdUDpB4v4hTlypBtuRIZw-9RLUtxI5EndTZ_AcT36ba84X67xBryqQTOHaJiDGgZbUuo-w=s250-k-rw-no}}'; // Replace with your image URL
#
# // Set canvas dimensions based on the image size
# canvas.width = image.width;
# canvas.height = image.height;
#
# // Initialize variables for user interaction
# let isDragging = false;
# let dragStartX = 0;
# let currentRotation = 0;
#
#   // Event listeners for mouse/touch interactions
# canvas.addEventListener('mousedown', (e) => {
#     isDragging = true;
#     dragStartX = e.clientX;
# });
#
# canvas.addEventListener('mouseup', () => {
#     isDragging = false;
# });
#
# canvas.addEventListener('mousemove', (e) => {
#     if (isDragging) {
#     const dragEndX = e.clientX;
#     const deltaX = dragEndX - dragStartX;
#     currentRotation += deltaX;
#     dragStartX = dragEndX;
#     drawImageWithRotation();
#     }
# });
#
#   // Function to draw the image with rotation
# function drawImageWithRotation() {
#     ctx.clearRect(0, 0, canvas.width, canvas.height);
#     ctx.save();
#     ctx.translate(canvas.width / 2, canvas.height / 2);
#     ctx.rotate((currentRotation * Math.PI) / 180); // Convert degrees to radians
#     ctx.drawImage(image, -image.width / 2, -image.height / 2);
#     ctx.restore();
# }
#
#   // Load and initially draw the image
# image.onload = () => {
#     drawImageWithRotation();
# };
# </script>
# Out:
# <canvas id="CarGarage"></canvas>
#
# <script>
# const canvas = document.getElementById("360Image");
# const ctx = canvas.getContext('2d');
#
# // Load your 360-degree image here
# const image = new Image();
# ...
