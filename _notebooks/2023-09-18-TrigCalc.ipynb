# %% [markdown]
# Here was our old code which we found overly redundant and hard to debug:
#
# ```python
#
# from cmath import pi
# import random
# import math
# print("If you want to type radicals, put rad() around your radical number. Ex: rad(2)/2. Type undefined answers as und. (with a period at the end)")
# while True:
#     operations = ["sin", "cos", "tan"]
#     angles = ["Ï€/6", "Ï€/4", "Ï€/3", "Ï€/2", "2Ï€/3", "3Ï€/4", "5Ï€/6", "Ï€", "7Ï€/6", "5Ï€/4", "4Ï€/3", "3Ï€/2", "5Ï€/3", "7Ï€/4", "11Ï€/6", "2pi"]
#     operation = random.choice(operations)
#     angle = random.choice(angles)
#     print(operation +  "(" + angle + ")")
#     answer = input("Enter your answer: ")
#     #Sine operations
#     if operation == "sin" and angle == "Ï€/6" and answer == "1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "Ï€/4" and answer == "rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "Ï€/3" and answer == "rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "Ï€/2" and answer == "1":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "2Ï€/3" and answer == "rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "3Ï€/4" and answer == "rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "5Ï€/6" and answer == "1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "Ï€" and answer == "0":
#         print("Congratulations, this is correct")
#     elif operation == "sin" and angle == "7Ï€/6" and answer == "-1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "5Ï€/4" and answer == "-rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "4Ï€/3" and answer == "-rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "3Ï€/2" and answer == "-1":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "5Ï€/3" and answer == "-rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "7Ï€/4" and answer == "-rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "11Ï€/6" and answer == "-1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "sin" and angle == "2Ï€" and answer == "0":
#         print("Congratulations, this is correct!")
#     #Cosine functions
#     elif operation == "cos" and angle == "Ï€/6" and answer == "rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "Ï€/4" and answer == "rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "Ï€/3" and answer == "1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "Ï€/2" and answer == "0":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "2Ï€/3" and answer == "-1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "3Ï€/4" and answer == "-rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "5Ï€/6" and answer == "-rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "Ï€" and answer == "-1":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "7Ï€/6" and answer == "-rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "5Ï€/4" and answer == "-rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "4Ï€/3" and answer == "-1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "3Ï€/2" and answer == "0":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "5Ï€/3" and answer == "1/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "7Ï€/4" and answer == "rad(2)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "11Ï€/6" and answer == "rad(3)/2":
#         print("Congratulations, this is correct!")
#     elif operation == "cos" and angle == "2Ï€" and answer == "1":
#         print("Congratulations, this is correct!")
#     #Tangent functions
#     elif operation == "tan" and angle == "Ï€/6" and answer == "rad(3)/3":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "Ï€/4" and answer == "1":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "Ï€/3" and answer == "rad(3)":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "Ï€/2" and answer == "und.":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "2Ï€/3" and answer == "-rad(3)":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "3Ï€/4" and answer == "-1":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "5Ï€/6" and answer == "-rad(3)/3":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "Ï€" and answer == "0":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "7Ï€/6" and answer == "rad(3)/3":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "5Ï€/4" and answer == "1":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "4Ï€/3" and answer == "rad(3)":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "3Ï€/2" and answer == "und":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "5Ï€/3" and answer == "-rad(3)":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "7Ï€/4" and answer == "-1":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "11Ï€/6" and answer == "-rad(3)/3":
#         print("Congratulations, this is correct!")
#     elif operation == "tan" and angle == "2Ï€" and answer == "0":
#         print("Congratulations, this is correct!")
#     else:
#         print("This is incorrect")
#
# ```
#
# Our new program below:

# %%
from cmath import pi
import random

# Create a dictionary to store answers for each operation and angle
answers = {
    "sin": {
        "Ï€/6": "1/2",
        "Ï€/4": "rad(2)/2",
        "Ï€/3": "rad(3)/2",
        "Ï€/2": "1",
        "2Ï€/3": "rad(3)/2",
        "3Ï€/4": "rad(2)/2",
        "5Ï€/6": "1/2",
        "Ï€": "0",
        "7Ï€/6": "-1/2",
        "5Ï€/4": "-rad(2)/2",
        "4Ï€/3": "-rad(3)/2",
        "3Ï€/2": "-1",
        "5Ï€/3": "-rad(3)/2",
        "7Ï€/4": "-rad(2)/2",
        "11Ï€/6": "-1/2",
        "2Ï€": "0",
    },
    "cos": {
        "Ï€/6": "rad(3)/2",
        "Ï€/4": "rad(2)/2",
        "Ï€/3": "1/2",
        "Ï€/2": "0",
        "2Ï€/3": "-1/2",
        "3Ï€/4": "-rad(2)/2",
        "5Ï€/6": "-rad(3)/2",
        "Ï€": "-1",
        "7Ï€/6": "-rad(3)/2",
        "5Ï€/4": "-rad(2)/2",
        "4Ï€/3": "-1/2",
        "3Ï€/2": "0",
        "5Ï€/3": "1/2",
        "7Ï€/4": "rad(2)/2",
        "11Ï€/6": "rad(3)/2",
        "2Ï€": "1",
    },
    "tan": {
        "Ï€/6": "rad(3)/3",
        "Ï€/4": "1",
        "Ï€/3": "rad(3)",
        "Ï€/2": "und.",
        "2Ï€/3": "-rad(3)",
        "3Ï€/4": "-1",
        "5Ï€/6": "-rad(3)/3",
        "Ï€": "0",
        "7Ï€/6": "rad(3)/3",
        "5Ï€/4": "1",
        "4Ï€/3": "rad(3)",
        "3Ï€/2": "und",
        "5Ï€/3": "-rad(3)",
        "7Ï€/4": "-1",
        "11Ï€/6": "-rad(3)/3",
        "2Ï€": "0",
    },
}


print("If you want to type radicals, put rad() around your radical number. Ex: rad(2)/2. Type undefined answers as und. (with a period at the end)")
print("To quit the program, type 'quit' or press 'q'.")

while True:
    operations = list(answers.keys())
    operation = random.choice(operations)
    angle = random.choice(list(answers[operation].keys()))

    print(operation +  "(" + angle + ")")
    answer = input("Enter your answer: ")

    if answer.lower() == "quit" or answer.lower() == "q":
        print("Goodbye!")
        break

    if answer == answers[operation][angle]:
        print("Congratulations, this is correct!")
    else:
        print("This is incorrect")
# Out:
# If you want to type radicals, put rad() around your radical number. Ex: rad(2)/2. Type undefined answers as und. (with a period at the end)
# To quit the program, type 'quit' or press 'q'.
# tan(11Ï€/6)
# Congratulations, this is correct!
# tan(5Ï€/3)
# This is incorrect
# tan(Ï€/3)
# Congratulations, this is correct!
# cos(Ï€/2)
# Congratulations, this is correct!
# sin(4Ï€/3)
# This is incorrect
# tan(Ï€/4)
# Goodbye!
